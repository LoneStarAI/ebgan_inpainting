# %%
import graphlab as gl
gl.canvas.set_target("ipynb")

# %%
# pt_weight: larger, more diversified generated images
# lambda: larger, more realistic image, but might off the contextual manifold;
# ??? sounds like larger lambda will lead to less releastic image

# Observation

# %%
orig = gl.image_analysis.load_images("./outputImgs/", recursive=False)
#lst = ["before", "completed", "hats", "masked"]
sorted_img = orig.sort(sort_columns="path", ascending=True)
sorted_img["image"].show()
sorted_img
# Out:
# Columns:
# 	path	str
# 	image	Image
#
# Rows: 4
#
# Data:
# +-------------------------------+------------------------+
# |              path             |         image          |
# +-------------------------------+------------------------+
# | /home/xeraph/OSS/ebgan/out... | Height: 112 Width: 224 |
# | /home/xeraph/OSS/ebgan/out... | Height: 112 Width: 224 |
# | /home/xeraph/OSS/ebgan/out... | Height: 112 Width: 224 |
# | /home/xeraph/OSS/ebgan/out... | Height: 112 Width: 224 |
# +-------------------------------+------------------------+
# [4 rows x 2 columns]

# %%
zhats = gl.image_analysis.load_images("./outputImgs/hats_imgs/")
zhats = zhats.sort(sort_columns="path", ascending=True)
zhats["image"].show()
#sf.show()
#completed = gl.image_analysis.load_images("./outputImgs/completed/")
#completed["image"].show()
